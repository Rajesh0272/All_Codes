# %%
#pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\M RAJESH\\Downloads\\Movie.csv")

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
a='123456789'
b=a[:-3]
print(b)
# Out:
# 123456

# %%
df.iloc[-5:-1]
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 4911                      2.0                   318.0  Daphne Zuniga
# 4912                      NaN                   319.0  Valorie Curry
# 4913                      0.0                     0.0  Maxwell Moody
# 4914                      0.0                   489.0  Daniel Henney
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# 4911                   637.0      NaN                  Comedy|Drama  ...
# 4912                   841.0      NaN  Crime|Drama|Mystery|Thriller  ...
# 4913                     0.0      NaN         Drama|Horror|Thriller  ...
# ...

# %%
df.loc[0:5,['country','title_year','budget']]
# Out:
#   country  title_year       budget
# 0     USA      2009.0  237000000.0
# 1     USA      2007.0  300000000.0
# 2      UK      2015.0  245000000.0
# 3     USA      2012.0  250000000.0
# 4     NaN         NaN          NaN
# 5     USA      2012.0  263700000.0

# %%
df.groupby('country').mean()
# Out:
#                       num_critic_for_reviews    duration  \
# country
# Afghanistan                       105.000000   83.000000
# Argentina                         114.750000  108.000000
# Aruba                              67.000000   91.000000
# Australia                         128.653846  104.750000
# Bahamas                            64.000000   94.000000
# ...                                      ...         ...
# Turkey                             16.000000  122.000000
# UK                                149.618056  109.591647
# USA                               141.561547  106.347732
# United Arab Emirates                     NaN   62.000000
# West Germany                       77.666667  155.666667
#
#                       director_facebook_likes  actor_3_facebook_likes  \
# country
# Afghanistan                          6.000000                0.000000
# Argentina                           68.000000               15.000000
# ...

# %%
df.groupby(['country'])[['title_year','budget']].nunique()
# Out:
#                       title_year  budget
# country
# Afghanistan                    1       1
# Argentina                      3       4
# Aruba                          1       1
# Australia                     28      38
# Bahamas                        1       1
# ...                          ...     ...
# Turkey                         1       1
# UK                            52     116
# USA                           90     360
# United Arab Emirates           1       1
# West Germany                   3       2
#
# [65 rows x 2 columns]

# %%
df.isnull().sum().sum()
# Out:
# 2654

# %%
df['director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
data = {'Platoon': ['A','A','A','A','A','A','B','B','B','B','B','C','C','C','C','C'],
       'Casualties': [1,4,5,7,5,5,6,1,4,5,6,7,4,6,4,8]}
d = pd.DataFrame(data)
d
# Out:
#    Platoon  Casualties
# 0        A           1
# 1        A           4
# 2        A           5
# 3        A           7
# 4        A           5
# 5        A           5
# 6        B           6
# 7        B           1
# 8        B           4
# 9        B           5
# 10       B           6
# 11       C           7
# 12       C           4
# 13       C           6
# 14       C           4
# 15       C           8

# %%
d.groupby(['Platoon'])['Casualties'].sum().iloc[1]
# Out:
# 22

# %%
d.at[4,'Casualties']
# Out:
# 5

# %%
s=df['num_critic_for_reviews'].abs()

# %%
s.sample(10)
# Out:
# 1684     85.0
# 3741     64.0
# 2775    357.0
# 3569     63.0
# 2420    217.0
# 3263     66.0
# 1456     93.0
# 2587     27.0
# 908     156.0
# 1848    226.0
# Name: num_critic_for_reviews, dtype: float64

# %%
i=df.columns.get_loc('num_critic_for_reviews')

# %%
i
# Out:
# 2

# %%
b = df.columns.is_monotonic_increasing 
b
# Out:
# False

# %%
c = df.columns.is_monotonic_decreasing 
c
# Out:
# False

# %%
df.index[-1]
# Out:
# 4915

# %%
df.index[1]
# Out:
# 1

# %%
df1= df.drop('num_critic_for_reviews',axis=1)

# %%
df1 = df.drop(['duration','gross'],axis=1)

# %%
len(df)
# Out:
# 4916

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
df2= df[df['gross']>=5.453055e+07]

# %%
df2['gross'].value_counts().sum()
# Out:
# 1146

# %%
import random as r
k = 20 
sel = r.sample(range(len(df2)) , k )

# %%
df_sample = df2.iloc[sel,:]

# %%
df_sample
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 65    Color        Bryan Singer                   396.0     144.0
# 67    Color         Pete Docter                   408.0      96.0
# 2366  Color      Robert Luketic                   163.0      96.0
# 86    Color       Anthony Russo                   576.0     136.0
# 883   Color  Guillermo del Toro                   224.0     117.0
# 461   Color          Shawn Levy                   147.0      93.0
# 1596  Color       Jason Reitman                   391.0     108.0
# 940   Color       Cameron Crowe                   257.0     124.0
# 1149  Color           Paul Feig                   270.0     123.0
# 319   Color       Steve Martino                   208.0      88.0
# 3964  Color         John Landis                    94.0     109.0
# 854   Color         Mark Waters                   189.0      94.0
# 1181  Color    Robert Rodriguez                    93.0      84.0
# ...

# %%
df2['director_name'].at[1885]
# Out:
# 'Adam McKay'

# %%
df.iloc[7]
# Out:
# color                                                                    Color
# director_name                                                     Nathan Greno
# num_critic_for_reviews                                                   324.0
# duration                                                                 100.0
# director_facebook_likes                                                   15.0
# actor_3_facebook_likes                                                   284.0
# actor_2_name                                                      Donna Murphy
# actor_1_facebook_likes                                                   799.0
# gross                                                              200807262.0
# genres                       Adventure|Animation|Comedy|Family|Fantasy|Musi...
# actor_1_name                                                      Brad Garrett
# movie_title                                                            Tangled
# ...

# %%
df.isna().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
df['gross'].fillna(79)
# Out:
# 0       760505847.0
# 1       309404152.0
# 2       200074175.0
# 3       448130642.0
# 4              79.0
#            ...
# 4911           79.0
# 4912           79.0
# 4913           79.0
# 4914        10443.0
# 4915        85222.0
# Name: gross, Length: 4916, dtype: float64

# %%
df['gross'].isnull().sum()
# Out:
# 862

# %%
df_new = pd.merge(left=df, right=d, 
 how='outer', left_index=True, 
 right_index=True)

# %%
df_new
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
from io import StringIO # python 3 
data = """Date,Pollster,State,Party,Est 
13/03/2014, Newspoll, NSW, red, 25 
13/03/2014, Newspoll, NSW, blue, 28 
13/03/2014, Newspoll, Vic, red, 24 
13/03/2014, Newspoll, Vic, blue, 23 
13/03/2014, Galaxy, NSW, red, 23 
13/03/2014, Galaxy, NSW, blue, 24 
13/03/2014, Galaxy, Vic, red, 26 
13/03/2014, Galaxy, Vic, blue, 25 
13/03/2014, Galaxy, Qld, red, 21 
13/03/2014, Galaxy, Qld, blue, 27""" 
df = pd.read_csv(StringIO(data), 
 header=0, skipinitialspace=True)

# %%
df
# Out:
#          Date  Pollster State Party  Est
# 0  13/03/2014  Newspoll   NSW   red    25
# 1  13/03/2014  Newspoll   NSW  blue    28
# 2  13/03/2014  Newspoll   Vic   red    24
# 3  13/03/2014  Newspoll   Vic  blue    23
# 4  13/03/2014    Galaxy   NSW   red    23
# 5  13/03/2014    Galaxy   NSW  blue    24
# 6  13/03/2014    Galaxy   Vic   red    26
# 7  13/03/2014    Galaxy   Vic  blue    25
# 8  13/03/2014    Galaxy   Qld   red    21
# 9  13/03/2014    Galaxy   Qld  blue    27

# %%
df1 = df.set_index(['Date', 'Pollster', 'State'])

# %%
df1
# Out:
#                           Party  Est
# Date       Pollster State
# 13/03/2014 Newspoll NSW     red    25
#                     NSW    blue    28
#                     Vic     red    24
#                     Vic    blue    23
#            Galaxy   NSW     red    23
#                     NSW    blue    24
#                     Vic     red    26
#                     Vic    blue    25
#                     Qld     red    21
#                     Qld    blue    27

# %%
wide1 = df1.pivot(columns='Party')

# %%
wide1
# Out:
#                           Est
# Party                     blue red
# Date       Pollster State
# 13/03/2014 Galaxy   NSW     24  23
#                     Qld     27  21
#                     Vic     25  26
#            Newspoll NSW     28  25
#                     Vic     23  24

# %%
df2 = df.set_index(['Date', 'Pollster', 'State', 'Party'])

# %%
df2
# Out:
#                                  Est
# Date       Pollster State Party
# 13/03/2014 Newspoll NSW   red      25
#                           blue     28
#                     Vic   red      24
#                           blue     23
#            Galaxy   NSW   red      23
#                           blue     24
#                     Vic   red      26
#                           blue     25
#                     Qld   red      21
#                           blue     27

# %%
wide2 = df2.unstack('State') 
wide3 = df2.unstack() # pop last index

# %%
wide2
# Out:
#                            Est
# State                       NSW   Qld   Vic
# Date       Pollster Party
# 13/03/2014 Galaxy   blue   24.0  27.0  25.0
#                     red    23.0  21.0  26.0
#            Newspoll blue   28.0   NaN  23.0
#                     red    25.0   NaN  24.0

# %%
wide3
# Out:
#                           Est
# Party                     blue red
# Date       Pollster State
# 13/03/2014 Galaxy   NSW     24  23
#                     Qld     27  21
#                     Vic     25  26
#            Newspoll NSW     28  25
#                     Vic     23  24

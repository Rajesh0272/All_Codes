# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.datasets import load_iris

# %%
ir=load_iris()

# %%
iris= pd.DataFrame(ir.data,columns=ir.feature_names)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris['target']=ir.target

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris['flower_names']=iris.target.apply(lambda x: ir.target_names[x])
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target flower_names
# ...

# %%
iris.iloc[37]
# Out:
# sepal length (cm)       4.9
# sepal width (cm)        3.6
# petal length (cm)       1.4
# petal width (cm)        0.1
# target                    0
# flower_names         setosa
# Name: 37, dtype: object

# %%
x=iris.drop(['target','flower_names'],axis=1)
y=iris.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 118                7.7               2.6                6.9               2.3
# 80                 5.5               2.4                3.8               1.1
# 37                 4.9               3.6                1.4               0.1
# 57                 4.9               2.4                3.3               1.0
# 33                 5.5               4.2                1.4               0.2
# ..                 ...               ...                ...               ...
# 82                 5.8               2.7                3.9               1.2
# 74                 6.4               2.9                4.3               1.3
# 119                6.0               2.2                5.0               1.5
# 86                 6.7               3.1                4.7               1.5
# 145                6.7               3.0                5.2               2.3
#
# [120 rows x 4 columns]

# %%
lr.predict([[4.9,3.6,1.4,0.1]])
# Out:
# C:\Users\M RAJESH\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 2, 1, 2, 0, 0, 2, 1, 2, 1, 1, 1, 2, 2, 0, 1, 1, 1, 2, 0, 0,
#        2, 1, 2, 2, 0, 2, 2, 2])

# %%
x_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 61                 5.9               3.0                4.2               1.5
# 59                 5.2               2.7                3.9               1.4
# 134                6.1               2.6                5.6               1.4
# 68                 6.2               2.2                4.5               1.5
# 105                7.6               3.0                6.6               2.1
# 16                 5.4               3.9                1.3               0.4
# 19                 5.1               3.8                1.5               0.3
# 116                6.5               3.0                5.5               1.8
# 97                 6.2               2.9                4.3               1.3
# 100                6.3               3.3                6.0               2.5
# 67                 5.8               2.7                4.1               1.0
# ...

# %%
plt.plot(iris['sepal length (cm)'],iris['sepal width (cm)'],'r*',linestyle='dashed',linewidth=2, markersize=12)

# %%
plt.scatter(iris['sepal length (cm)'],iris['sepal width (cm)'])

# %%
plt.subplot(2,2,1)
plt.plot(iris['sepal length (cm)'],iris['sepal width (cm)'],'r--')
plt.subplot(2,2,2)
plt.plot(iris['petal length (cm)'],iris['petal width (cm)'],'g*--')
plt.figure(figsize=(20,14))

# %%
plt.bar(iris['sepal length (cm)'],iris['sepal width (cm)'],width=0.1,color='g')
# Out:
# <BarContainer object of 150 artists>

# %%
plt.hist(iris['sepal length (cm)'],bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.pie(iris['target'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2110fb24670>,
# ...
#  [Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
# ...

# %%
sns.distplot(iris['sepal length (cm)'])
# Out:
# C:\Users\M RAJESH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='Density'>

# %%
sns.distplot(iris['sepal length (cm)'],kde=False)
# Out:
# C:\Users\M RAJESH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal length (cm)'>

# %%
sns.pairplot(iris,hue='target')

# %%
sns.violinplot(iris['target'],iris['sepal length (cm)'])
# Out:
# C:\Users\M RAJESH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='sepal length (cm)'>

# %%
sns.boxplot(iris['target'],iris['sepal length (cm)'])
# Out:
# C:\Users\M RAJESH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='sepal length (cm)'>

# %%
sns.jointplot(iris['target'],iris['sepal length (cm)'])
# Out:
# C:\Users\M RAJESH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a=[-10,1,1,1,2,3,6,100]
b=sum(a)

# %%
b/len(a)
# Out:
# 13.0

# %%
c=[1,2,2,3,4,5]
d=sum(c)

# %%
d
# Out:
# 17

# %%
d/len(c)
# Out:
# 2.8333333333333335

# %%
import math
math.sqrt(1.83)
# Out:
# 1.3527749258468684

# %%
1.35+2.83
# Out:
# 4.18

# %%
2.83-(2*1.35)
# Out:
# 0.1299999999999999

# %%
x=[2,2,3,4,5,5,5,7,8,8,8,8,9,9,10,11,11,12]

# %%
14/18
# Out:
# 0.7777777777777778

# %%
sum(x)
# Out:
# 127

# %%
0.25*19
# Out:
# 4.75

# %%
y=[1,2,2,3,3,4,5,5,5,6,6,6,6,7,8,8,9,27]
0.25*20
# Out:
# 5.0

# %%
0.25*20
# Out:
# 5.0

# %%
0.75*20
# Out:
# 15.0

# %%
len(y)
# Out:
# 18

# %%
0.5*20
# Out:
# 10.0

# %%
3-(1.5*4)
# Out:
# -3.0

# %%
7+(1.5*4)
# Out:
# 13.0

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21111d44040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21111d445e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21111d37d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x21111d44b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21111d44e50>],
#  'means': []}

# %%
v=pd.DataFrame(y)

# %%
v.describe()
# Out:
#                0
# count  18.000000
# mean    6.277778
# std     5.633989
# min     1.000000
# 25%     3.250000
# 50%     5.500000
# 75%     6.750000
# max    27.000000

# %%
3.25-(1.5*(6.75-3.25))
# Out:
# -2.0

# %%
r=[1,1,1,2,2,3,4,4,5,5,5,6]
g=pd.DataFrame(r)

# %%
g.describe()
# Out:
#                0
# count  12.000000
# mean    3.250000
# std     1.815339
# min     1.000000
# 25%     1.750000
# 50%     3.500000
# 75%     5.000000
# max     6.000000

# %%
1.75-(1.5*(5-1.75))
# Out:
# -3.125

# %%
1.75+(1.5*(5-1.75))
# Out:
# 6.625

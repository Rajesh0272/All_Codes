# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\M RAJESH\\Downloads\\Movie.csv")

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
a='123456789'
b=a[:-3]
print(b)
# Out:
# 123456

# %%
df.iloc[-5:-1]
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 4911                      2.0                   318.0  Daphne Zuniga
# 4912                      NaN                   319.0  Valorie Curry
# 4913                      0.0                     0.0  Maxwell Moody
# 4914                      0.0                   489.0  Daniel Henney
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# 4911                   637.0      NaN                  Comedy|Drama  ...
# 4912                   841.0      NaN  Crime|Drama|Mystery|Thriller  ...
# 4913                     0.0      NaN         Drama|Horror|Thriller  ...
# ...

# %%
df.loc[0:5,['country','title_year','budget']]
# Out:
#   country  title_year       budget
# 0     USA      2009.0  237000000.0
# 1     USA      2007.0  300000000.0
# 2      UK      2015.0  245000000.0
# 3     USA      2012.0  250000000.0
# 4     NaN         NaN          NaN
# 5     USA      2012.0  263700000.0

# %%
df.groupby('country').mean()
# Out:
#                       num_critic_for_reviews    duration  \
# country
# Afghanistan                       105.000000   83.000000
# Argentina                         114.750000  108.000000
# Aruba                              67.000000   91.000000
# Australia                         128.653846  104.750000
# Bahamas                            64.000000   94.000000
# ...                                      ...         ...
# Turkey                             16.000000  122.000000
# UK                                149.618056  109.591647
# USA                               141.561547  106.347732
# United Arab Emirates                     NaN   62.000000
# West Germany                       77.666667  155.666667
#
#                       director_facebook_likes  actor_3_facebook_likes  \
# country
# Afghanistan                          6.000000                0.000000
# Argentina                           68.000000               15.000000
# ...

# %%
df.groupby(['country'])[['title_year','budget']].nunique()
# Out:
#                       title_year  budget
# country
# Afghanistan                    1       1
# Argentina                      3       4
# Aruba                          1       1
# Australia                     28      38
# Bahamas                        1       1
# ...                          ...     ...
# Turkey                         1       1
# UK                            52     116
# USA                           90     360
# United Arab Emirates           1       1
# West Germany                   3       2
#
# [65 rows x 2 columns]

# %%
df.isnull().sum().sum()
# Out:
# 2654

# %%
df['director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
data = {'Platoon': ['A','A','A','A','A','A','B','B','B','B','B','C','C','C','C','C'],
       'Casualties': [1,4,5,7,5,5,6,1,4,5,6,7,4,6,4,8]}
d = pd.DataFrame(data)
d
# Out:
#    Platoon  Casualties
# 0        A           1
# 1        A           4
# 2        A           5
# 3        A           7
# 4        A           5
# 5        A           5
# 6        B           6
# 7        B           1
# 8        B           4
# 9        B           5
# 10       B           6
# 11       C           7
# 12       C           4
# 13       C           6
# 14       C           4
# 15       C           8

# %%
d.groupby(['Platoon'])['Casualties'].sum().iloc[1]
# Out:
# 22

# %%
d.at[4,'Casualties']
# Out:
# 5

# %%
s=df['num_critic_for_reviews']
